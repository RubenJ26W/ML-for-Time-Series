# %% [markdown]
# **Machine Learning for Time Series (Master MVA)**
#
# - TP1, Thursday 16<sup>th</sup> October 2025
# - [Link to the class material.](http://www.laurentoudre.fr/ast.html)

# %% [markdown]
# # Introduction
#
# In this tutorial, we focus on the task of **clustering time series**. Through several examples, we will highlight the specific challenges that arise from the **temporal structure** of the data.
#
# We will address these challenges using several key concepts introduced in the lessons:
#
# - Dynamic Time Warping (DTW)
#
# - Convolutional Dictionary Learning
#
# - Feature Extraction
#
# - Feature Selection

# %% [markdown]
# # Setup
#
# **Imports**

# %%
from itertools import tee

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import rgb2hex

import numpy as np 
import pandas as pd

#import a data loader
from aeon.datasets import load_classification
#dtw computations
from dtw import dtw
#compare computation times
import time
#hierarchical clustering
from scipy.cluster import hierarchy
from scipy.stats import f_oneway 


from scipy.spatial.distance import pdist, squareform
from sklearn.metrics import adjusted_rand_score, make_scorer, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SequentialFeatureSelector

from alphacsc import learn_d_z
try:
    from alphacsc.utils import construct_X
except:
    from alphacsc.utils.convolution import construct_X

from scipy.signal import argrelmax

# %% [markdown]
# **Utilitary functions**

# %%
def display_distance_matrix_as_table(
    distance_matrix, labels=None, figsize=(8, 2)
):
    fig, ax = plt.subplots(figsize=figsize)
    ax.axis("tight")
    ax.axis("off")
    norm = mpl.colors.Normalize()
    cell_colours_hex = np.empty(shape=distance_matrix.shape, dtype=object)
    cell_colours_rgba = plt.get_cmap("magma")(norm(distance_matrix))

    for i in range(distance_matrix.shape[0]):
        for j in range(i + 1, distance_matrix.shape[0]):
            cell_colours_hex[i, j] = rgb2hex(
                cell_colours_rgba[i, j], keep_alpha=True
            )
            cell_colours_hex[j, i] = cell_colours_hex[i, j]

    if labels is not None:
        _ = ax.table(
            cellText=distance_matrix,
            colLabels=labels,
            rowLabels=labels,
            loc="center",
            cellColours=cell_colours_hex,
        )
    else:
        _ = ax.table(
            cellText=distance_matrix,
            loc="center",
            cellColours=cell_colours_hex,
        )

    return ax

def plot_CDL(signal, Z, D, figsize=(15, 10)):
    """Plot the learned dictionary `D` and the associated sparse codes `Z`.

    `signal` is an univariate signal of shape (n_samples,) or (n_samples, 1).
    """
    (atom_length, n_atoms) = np.shape(D)
    plt.figure(figsize=figsize)
    plt.subplot(n_atoms + 1, 3, (2, 3))
    plt.plot(signal)
    for i in range(n_atoms):
        plt.subplot(n_atoms + 1, 3, 3 * i + 4)
        plt.plot(D[:, i])
        plt.subplot(n_atoms + 1, 3, (3 * i + 5, 3 * i + 6))
        plt.plot(Z[:, i])
        plt.ylim((np.min(Z), np.max(Z)))

def get_n_largest(
    arr: np.ndarray, n_largest: int = 3) -> (np.ndarray, np.ndarray):
    """Return the n largest values and associated indexes of an array.

    (In decreasing order of value.)
    """
    indexes = np.argsort(arr)[-n_largest:][::-1]
    if n_largest == 1:
        indexes = np.array(indexes)
    values = np.take(arr, indexes)
    return values, indexes

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

def get_largest_local_max(signal1D: np.ndarray, order: int = 1):
    """Return the largest local max and the associated index in a tuple.

    This function uses `order` points on each side to use for the comparison.
    """
    all_local_max_indexes = argrelmax(signal1D, order=order)[0]
    all_local_max = np.take(signal1D, all_local_max_indexes)
    largest_local_max_index = all_local_max_indexes[all_local_max.argsort()[-1]]

    return signal1D[largest_local_max_index], largest_local_max_index

# %% [markdown]
# # Clustering in Time Series

# %% [markdown]
# **Clustering** is an unsupervised learning task that aims to **group similar data points** together into clusters, so that objects in the same cluster are more similar to each other than to those in different clusters.
#
# ### How to define similarity for time series ?
#
# For time series, defining a meaningful similarity (or distance) is challenging. Typical issues include:
#
# - **Amplitude differences and offset shifts**. *Problem:* Series may have the same shape but different offsets or amplitudes.
# *Solution:* Normalize series (e.g., z-normalization) to focus on relative shape rather than absolute values.
#
# - **Time shifts (temporal misalignment)**.
# *Problem:* Similar events may occur at slightly different times.
# *Solution:* Use alignment-based measures such as Dynamic Time Warping (DTW).

# %% [markdown]
# # 1. DTW vs Euclidean Distance
#
# ##  Dataset example
#
# FiftyWords is a data set of word outlines taken from the George
# Washington library by T. Rath and used in the paper "Word image
# matching using dynamic time warping", CVPR 2003.
#
# Each case is a word. A series is formed by taking the height
# profile of the word.
#
# ![image](alexandria.png)

# %% [markdown]
# Here, we only deal with the top profile (in red).

# %%
#loading data
profiles, labels= load_classification("FiftyWords")
profiles=np.squeeze(profiles)

# normalize signals (zero mean, unit variance).
profiles -= profiles.mean(axis=1).reshape(-1,1)
profiles /= profiles.std(axis=1).reshape(-1,1)

# %% [markdown]
# Let's visualize two examples from the same class.

# %%
labels_1=np.where(labels=='1')[0]
word_1, y_1= profiles[labels_1[0]], labels[labels_1[0]]
word_2, y_2=profiles[labels_1[3]], labels[labels_1[3]]

figsize=(15, 5)
fig, ax = plt.subplots(figsize=figsize)

ax.plot(word_1, label=y_1)
ax.plot(word_2, label=y_2)
_ = plt.legend()

# %% [markdown]
# ## DTW between 2 signals

# %%
alignment = dtw(word_1, word_2, keep_internals=True)
figsize=(15, 5)
fig, ax = plt.subplots(figsize=figsize)
ax.plot(word_1, label=y_1)
ax.plot(word_2, label=y_2)
plt.title(f"DTW: {alignment.distance:.2f}")
_ = plt.legend()

# %%
alignment.plot(type="threeway")
# Out:
# <Axes: >

# %%
alignment.plot(type="twoway", offset=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 alignment.plot(type="twoway", offset=10)
#
# File c:\Users\shubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtw\dtw.py:124, in DTW.plot(self, type, **kwargs)
#      84         """Plotting of dynamic time warp results
#      85
#      86 Methods for plotting dynamic time warp alignment objects returned by
#    (...)
#     121
#     122 """
#     123         # ENDIMPORT
# --> 124         return dtwPlot(self, type, **kwargs)
#
# File c:\Users\shubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtw\dtwPlot.py:70, in dtwPlot(x, type, **kwargs)
#      68     return dtwPlotAlignment(x, **kwargs)
#      69 elif type == "twoway":
# ---> 70     return dtwPlotTwoWay(x, **kwargs)
#      71 elif type == "threeway":
#      72     return dtwPlotThreeWay(x, **kwargs)
#
# File c:\Users\shubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtw\dtwPlot.py:197, in dtwPlotTwoWay(d, xts, yts, offset, ts_type, match_indices, match_col, xlab, ylab, **kwargs)
#     193 for i in idx:
#     194     col.append([(d.index1[i], xts[d.index1[i]]),
#     195                 (d.index2[i], -offset + yts[d.index2[i]])])
# --> 197 lc = mc.LineCollection(col, linewidths=1, linestyles=":", colors=match_col)
#     198 ax.add_collection(lc)
#     200 return ax
#
# File c:\Users\shubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:1396, in LineCollection.__init__(self, segments, zorder, **kwargs)
#    1392 kwargs.setdefault('facecolors', 'none')
#    1393 super().__init__(
#    1394     zorder=zorder,
#    1395     **kwargs)
# -> 1396 self.set_segments(segments)
#
# File c:\Users\shubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:1403, in LineCollection.set_segments(self, segments)
#    1399 if segments is None:
#    1400     return
#    1402 self._paths = [mpath.Path(seg) if isinstance(seg, np.ma.MaskedArray)
# -> 1403                else mpath.Path(np.asarray(seg, float))
#    1404                for seg in segments]
#    1405 self.stale = True
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 2) + inhomogeneous part.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Write a function which computes the DTW distance between two signals using the dtw module: <tt>get_dtw_distance(signal_1: np.ndarray, signal_2: np.ndarray)->float</tt>.</p>
# </div>

# %%
def get_dtw_distance(signal_1,signal_2):
    return dtw(signal_1, signal_2, keep_internals=True).distance

def get_euclidean_distance(signal_1,signal_2):
    return np.linalg.norm(signal_1 - signal_2)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Choose one of the two words and plot the most similar and the most dissimilar, according to the DTW. In addition, print the associated labels.</p>
# </div>

# %%
distances=[]

start = time.time()
for word in profiles:
    distances.append(get_dtw_distance(word_1,word))
end= time.time()

sorted_idx = np.argsort(distances)
arg_max=sorted_idx[-1]
arg_min=sorted_idx[1]

max_word, max_label =profiles[arg_max], labels[arg_max]
min_word, min_label =profiles[arg_min], labels[arg_min]

figsize=(15, 5)
fig, ax = plt.subplots(figsize=figsize)

ax.plot(word_1, label=y_1)
ax.plot(max_word, label=max_label)
ax.plot(min_word, label=min_label)
_ = plt.legend()
print('execution_time: ' +str(end-start) +'s')
# Out:
# execution_time: 1.694094181060791s

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Repeat the same procedure with the Euclidean distance. Compare the results and the computation times with DTW (you may use the time module).</p>
# </div>

# %%
distances=[]

start = time.time()
for word in profiles:
    distances.append(get_euclidean_distance(word_1,word))
end= time.time()

sorted_idx = np.argsort(distances)
arg_max=sorted_idx[-1]
arg_min=sorted_idx[1]

max_word, max_label =profiles[arg_max], labels[arg_max]
min_word, min_label =profiles[arg_min], labels[arg_min]

figsize=(15, 5)
fig, ax = plt.subplots(figsize=figsize)

ax.plot(word_1, label=y_1)
ax.plot(max_word, label=max_label)
ax.plot(min_word, label=min_label)
_ = plt.legend()
print('execution_time: ' +str(end-start) +'s')
# Out:
# execution_time: 0.0038766860961914062s

# %% [markdown]
# ## Clustering with DTW

# %% [markdown]
# ### Clustering a small subset
#
# Out of the whole data set, let us choose 6 word profiles from 2 classes.

# %%
# select a few profiles with two different classes
keep_mask = np.isin(labels, ["31", "34"])
labels_sub = labels[keep_mask]
profiles_sub = profiles[keep_mask]
# reorder by label
order_indexes = labels_sub.argsort()
labels_sub = labels_sub[order_indexes]
profiles_sub = profiles_sub[order_indexes]

# %%
# init
distance_matrix = np.zeros(
    (profiles_sub.shape[0], profiles_sub.shape[0]), dtype=float
)

for row in range(profiles_sub.shape[0]):
    for col in range(row + 1, profiles_sub.shape[0]):
        distance_matrix[row, col] = get_dtw_distance(
            profiles_sub[row], profiles_sub[col]
        )
        distance_matrix[col, row] = distance_matrix[row, col]

# %%
_ = display_distance_matrix_as_table(
    np.round(distance_matrix, 2), labels=labels_sub
)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Create the same plot (distance matrix) with the Euclidean distance instead of the DTW. What do you observe?</p>
# </div>

# %%
euclidean_distance_matrix=euclidean_distance_matrix= np.zeros((profiles_sub.shape[0], profiles_sub.shape[0]), dtype=float)
for row in range(profiles_sub.shape[0]):
    for col in range(row + 1, profiles_sub.shape[0]):
        euclidean_distance_matrix[row, col] = get_euclidean_distance(profiles_sub[row], profiles_sub[col])
        euclidean_distance_matrix[col, row] = euclidean_distance_matrix[row, col]

# %%
_ = display_distance_matrix_as_table(
    np.round(euclidean_distance_matrix, 2), labels=labels_sub
)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>One of the most popular clustering algorithms is K-Means. What difficulties or limitations might you encounter when trying to use standard K-Means with DTW?</p>
# </div>

# %% [markdown]
# To overcome these difficulties, we use a hierarchical clustering algorithm.

# %%
# Compute linkage matrix using the 'Ward' criterion
linkage = hierarchy.ward(distance_matrix)

figsize=(20, 10)
fig, ax = plt.subplots(figsize=figsize)

cut_threshold = 200

dendro = hierarchy.dendrogram(
    linkage,
    ax=ax,
    labels=labels_sub,
    color_threshold=cut_threshold,
    distance_sort=True,
)
ax.axhline(cut_threshold, ls="--", color="k")
# Out:
# c:\Users\shubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\cluster\hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %%
labels_pred = hierarchy.fcluster(linkage, t=cut_threshold, criterion='distance')
ari=adjusted_rand_score(labels_sub,labels_pred)
ari
# Out:
# 1.0

# %% [markdown]
# ### Clustering on a larger subset
#
# Using the DTW, we can cluster a large set of data (43 words).

# %%
# select a few profiles with two different classes
keep_mask = np.isin(labels, ["4", "6", "14"])
profiles_sub = profiles[keep_mask]
labels_sub = labels[keep_mask]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Compare the clustering produced by DTW and Euclidean distance by plotting dendrograms, choosing a cut_threshold to form homogeneous clusters, and evaluating the results with the Adjusted Rand Index (ARI). Discuss which distance better captures time series similarity.</p>
# </div>

# %%
# Instead of the previous double for loop, we can use scipy function pdist
dtw_distance_matrix = pdist(
    profiles_sub.squeeze(), metric=get_dtw_distance
)  # condensed distance matrix

# %%
# Compute linkage matrix using the 'Ward' criterion
linkage = hierarchy.ward(dtw_distance_matrix)

figsize = (20, 10)
fig, ax = plt.subplots(figsize=figsize)

cut_threshold = 220

dendro = hierarchy.dendrogram(
    linkage,
    ax=ax,
    labels=labels_sub,
    color_threshold=cut_threshold,
    distance_sort=True,
)

ax.axhline(cut_threshold, ls="--", color="k")

# %%
cut_threshold = ...

# %%
# Instead of the previous double for loop, we can use scipy function pdist
euclidean_distance_matrix = pdist(
    profiles_sub.squeeze(), metric=get_euclidean_distance
)  # condensed distance matrix

# %%
# Compute linkage matrix using the 'Ward' criterion
linkage = hierarchy.ward(euclidean_distance_matrix)

figsize = (20, 10)
fig, ax = plt.subplots(figsize=figsize)

cut_threshold = 70

dendro = hierarchy.dendrogram(
    linkage,
    ax=ax,
    labels=labels_sub,
    color_threshold=cut_threshold,
    distance_sort=True,
)

ax.axhline(cut_threshold, ls="--", color="k")

# %%
labels_pred = hierarchy.fcluster(linkage, t=cut_threshold, criterion='distance')
ari = adjusted_rand_score(labels_sub, labels_pred)
ari
# Out:
# 0.3267862393413702

# %%
cut_threshold = ...

# %% [markdown]
# # 2. Clustering at the scale of atoms

# %% [markdown]
# Up to now, we have considered time series where class differences could be observed at the **global scale** of the signal. However, in many real-world applications the discriminative information is not visible over the whole series but rather at the level of **local patterns (atoms)**.

# %% [markdown]
# ## Dataset example

# %% [markdown]
# Task is to classify the nature of the heartbeat signal.
#
# Heart sound recordings were sourced from several contributors around the world, collected at either a clinical or nonclinical environment, from both healthy subjects and pathological patients.
# Each series represent the amplitude of the signal over time.
#
# Heart sound recordings were sourced from several contributors around the world, collected at either a clinical or nonclinical environment, from both healthy subjects and pathological patients.
# The heart sound recordings were collected from different locations on the body. The typical four locations are aortic area, pulmonic area, tricuspid area and mitral area, but could be one of nine different locations.
# The sounds were divided into two classes: normal and abnormal. The normal recordings were from healthy subjects and the abnormal ones were from patients with a confirmed cardiac diagnosis.
# The patients suffer from a variety of illnesses, but typically they are heart valve defects and coronary artery disease patients.
# Heart valve defects include mitral valve prolapse, mitral regurgitation, aortic stenosis and valvular surgery. All the recordings from the patients were generally labeled as abnormal.
# Both healthy subjects and pathological patients include both children and adults.
#
# Data was recorded at 2,000Hz.
# Data was truncated to the shortest instance.
#
# Original data can be found here:
# https://www.physionet.org/physiobank/database/challenge/2016/
#
# Original paper:
# Goldberger AL, Amaral LA, Glass L, Hausdorff JM, Ivanov PC, Mark RG, Mietus JE, Moody GB, Peng CK, Stanley HE. PhysioBank, PhysioToolkit, and PhysioNet: components of a new research resource for complex physiologic signals. circulation. 2000 Jun 13;101(23):e215-20.
#
# Correspondence should be addressed to Ary L. Goldberger:
# ary@astro.bidmc.harvard.edu
#
# Instances: 409
#
# Time series length: 18,530
#
# Classes:
# - Normal (110)
# - Abnormal (299)

# %%
X, y= load_classification("BinaryHeartbeat")
X=X.squeeze()

# %% [markdown]
# We can plot a signal from each class (normal and abnormal).

# %%
FREQUENCY = 2000  # Hz

fig, ax_arr = plt.subplots(nrows=1, ncols=2, figsize=(20, 3), sharey=True)
fig.tight_layout()
for ind, ax in zip([1, 200], ax_arr):
    s = X[ind]
    tt = np.arange(s.size) / FREQUENCY
    ax.plot(tt, s)
    ax.set_xlim(0, s.size / FREQUENCY)
    ax.set_xlabel("Time (s)")
    _ = ax.set_title(f"label: {y[ind]}")

# %% [markdown]
# For the subsequent study, we select only 6 elements (3 from each classe) from the complete data set.

# %%
sub_sample = [0, 1, 2, 190, 191, 192]  # 3 Normal, 3 Abnormal
sub_X = np.take(
    X, sub_sample, axis=0
).squeeze()  # shape (n_series, n_samples)
sub_y = np.take(y, sub_sample, axis=0)  # shape (n_series,)

# normalize signals (zero mean, unit variance).
sub_X -= sub_X.mean(axis=1).reshape(-1, 1)
sub_X /= sub_X.std(axis=1).reshape(-1, 1)

# %% [markdown]
# Let's zoom to see in more details the events of interest.

# %%
inds = [2, 4]  # indices des signaux à afficher
fig, ax_arr = plt.subplots(nrows=2, ncols=2, figsize=(20, 6), sharey=True)
fig.tight_layout(pad=4)

for row, ind in enumerate(inds):
    signal = sub_X[ind]
    label = sub_y[ind]
    n_samples = signal.size
    tt = np.arange(n_samples) / FREQUENCY

    # Signal complet
    ax = ax_arr[row, 0]
    ax.plot(tt, signal)
    ax.set_xlabel("Time (s)")
    ax.set_xlim(0, n_samples / FREQUENCY)
    ax.set_title(f"Signal index {ind}, label: {label}")

    # Zoom sur un segment
    ax = ax_arr[row, 1]
    start, end = 0, 4000  # ajuster selon le zoom souhaité
    ax.plot(tt[start:end], signal[start:end])
    ax.set_xlim(tt[start], tt[end])
    ax.set_xlabel("Time (s)")
    ax.set_title(f"Zoom on [{start/FREQUENCY:.2f}s, {end/FREQUENCY:.2f}s]")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Roughly, what is the duration of the important phenomenon (the heartbeat)?</p>
# </div>

# %% [markdown]
# To compare the signals at a finer scale, we need to extract their elementary atoms. One way to achieve this is through Convolutional Dictionary Learning (CDL).

# %% [markdown]
# ## CDL on a single signal
#
# For a 1D signal $\mathbf{x}\in\mathbb{R}^N$ with $N$ samples, the convolutional dictionary learning tasks amounts to solving the following optimization problem:
#
# $$
# \min_{(\mathbf{d}_k)_k, (\mathbf{z}_k)_k \\ \lVert\mathbf{d}_k\rVert^2\leq 1} \quad (1/2)\left\lVert \mathbf{x} - \sum_{k=1}^K \mathbf{z}_k * \mathbf{d}_k \right\rVert^2 \quad + \quad\lambda \sum_{k=1}^K \lVert\mathbf{z}_k\rVert_1
# $$
#
# where $\mathbf{d}_k\in\mathbb{R}^L$ are the $K$ dictionary atoms (patterns), $\mathbf{z}_k\in\mathbb{R}^{N-L+1}$ are activations signals, and $\lambda>0$ is the sparsity constraint.
#
# This problem is not convex with respect to the couple $(\mathbf{d}_k)_k, (\mathbf{z}_k)_k$ but convex when the subproblems are taken individually.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>What are the parameters that a user must calibrate when using CDL?</p>
# </div>

# %% [markdown]
# We can now apply CDL on a single signal.

# %%
# Select a signal
signal = sub_X[2]
data = signal[np.newaxis, :]  # shape (1, n_samples)

# %%
# Parameters to change
n_atoms = 2  # K
atom_length = 2000//4  # L for 2.5 s
penalty = 4  # lambda

# %%
# learning a dictionary and codes
pobj, _, d_hat, z_hat, _ = learn_d_z(
    X=data,
    n_atoms=n_atoms,
    n_times_atom=atom_length,
    reg=penalty,
    n_iter=30,
    n_jobs=3,
    verbose=1)
# Out:
# V_0/30 .............................

# %%
# plot the results
plot_CDL(signal, z_hat.T.squeeze(), d_hat.T.squeeze())

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>How does the number of activation evolve when the sparsity penalty changes?</p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Looking at the sparse codes, can you tell:</p>
#     <ul>
#     <li>How many times each atom is activated?</li>
#     <li>What is the compression rate (number of non-zero coefficients in the sparse codes / signal length)?</li>
#     </ul>
# </div>

# %%
# Reconstruction with the dictionary and the sparse codes
reconstruction = construct_X(z_hat, d_hat).squeeze()

figsize=(15, 5)
fig, ax = plt.subplots(figsize=figsize)
tt = np.arange(signal.shape[0])
ax.plot(tt, signal, label="original", alpha=0.5)
ax.plot(tt, reconstruction, label="reconstructed")

ax.set_title(f"Reconstruction MSE: {np.mean((signal - reconstruction)**2):.2e}")

_ = plt.legend()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>How does reconstruction error evolve when the sparsity penalty changes?</p>
# </div>

# %%
z1 = z_hat[0, 0, :]
z2 = z_hat[1, 0, :]

activation1 = np.sum(z1 != 0.0)
activation2 = np.sum(z2 != 0.0)

# %%
activation1, activation2
# Out:
# (np.int64(1749), np.int64(1542))

# %%
compression_ratio1 = activation1 / len(signal)
compression_ratio2 = activation2 / len(signal)

# %%
compression_ratio1, compression_ratio2
# Out:
# (np.float64(0.09438747976254722), np.float64(0.0832164058283864))

# %%
fig, ax_arr = plt.subplots(
    nrows=n_atoms // 3 + 1,
    ncols=3,
    figsize=(20, 4 * (n_atoms // 3 + 1)),
    sharey=True,
)

for k in range(n_atoms):
    ax = ax_arr.flatten()[k]
    reconstruted_with_one_atom = construct_X(
        z_hat[k, np.newaxis, :, :], d_hat[k, np.newaxis, :]
    ).squeeze()
    ax.plot(range(start, end), signal[start:end])
    ax.plot(
        range(start, end),
        reconstruted_with_one_atom[start:end],
    )
    ax.set_title(f"Atom {k} only")

ax = ax_arr.flatten()[n_atoms]
ax.plot(range(start, end), signal[start:end])
ax.plot(
    range(start, end),
    reconstruction[start:end],
)
_ = ax.set_title(f"All atoms")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Rerun the dictionary learning and sparse coding. What do you observe on the motif shape? And the reconstruction error?</p>
# </div>

# %% [markdown]
# ## CDL on the whole data set
#
# In this section, we apply CDL on the whole data set.

# %%
# In the following, we fix the number of atoms and their length
n_atoms = 2
atom_length = 2000//4
penalty = 4

# %%
sub_X.shape
# Out:
# (6, 18530)

# %% [markdown]
# Dictionary learning.

# %%
pobj, _, d_hat, z_hat, _ = learn_d_z(
    X=sub_X,
    n_atoms=n_atoms,
    n_times_atom=atom_length,
    reg=penalty,
    verbose=1,
    n_jobs=3,
    n_iter=30,
)
# Out:
# V_0/30
# .............................

# %%
fig, ax_arr = plt.subplots(
    nrows=n_atoms // 3 + 1,
    ncols=3,
    figsize=(20, 4 * (n_atoms // 3 + 1)),
    sharey=True,
)

for k, (atom, ax) in enumerate(zip(d_hat, ax_arr.flatten())):
    ax.plot(atom)
    ax.set_xlim(0, atom.size)
    ax.set_title(f"Atom {k}")

# %%
for k, (label, signal) in enumerate(zip(sub_y, sub_X)):
    codes = z_hat[:, k, :]
    reconstruction = construct_X(codes[:, np.newaxis, :], d_hat).squeeze()
    error = np.mean((signal - reconstruction) ** 2)
    nnz_activations = (codes > 1e-3).sum()

    # select the used atoms
    most_used_atoms_activations, most_used_atoms_indexes = get_n_largest(
        (codes > 1e-3).sum(axis=1), n_largest=1
    )
    most_used_atom_msg = ", ".join(
        f"{ind} ({acti*100/nnz_activations:.1f}%)"
        for (acti, ind) in zip(
            most_used_atoms_activations, most_used_atoms_indexes
        )
    )
    print(
        f"Label: {label}, MSE: {error:.2f}, non-zero activations: {nnz_activations}, most used atoms: {most_used_atom_msg}"
    )
# Out:
# Label: 0, MSE: 0.41, non-zero activations: 4202, most used atoms: 0 (60.1%)
# Label: 0, MSE: 0.50, non-zero activations: 5091, most used atoms: 0 (70.3%)
# Label: 0, MSE: 0.23, non-zero activations: 2678, most used atoms: 0 (58.1%)
# Label: 1, MSE: 0.45, non-zero activations: 5063, most used atoms: 0 (65.4%)
# Label: 1, MSE: 0.29, non-zero activations: 2746, most used atoms: 1 (53.2%)
# Label: 1, MSE: 0.22, non-zero activations: 3376, most used atoms: 0 (54.8%)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Based on the results, does this approach appear suitable for effectively clustering such time series?</p>
# </div>

# %% [markdown]
# # 3. Clustering via Feature Selection

# %% [markdown]
# The final approach we consider in this lab is more closely related to traditional machine learning methods. It consists in extracting a well-chosen set of features from the time series and subsequently applying standard clustering algorithms.
#
#
# In the following, we will use the same dataset as before. Let’s start by examining in detail the different features that can be extracted from an example time series.

# %%
ind=0
signal=X[0]
label = y[ind]
n_samples = signal.shape[0]
print(label)
# Out:
# 0

# %% [markdown]
# ## 3.a. Statistical features

# %% [markdown]
# ### Moment and percentiles

# %%
def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max() 
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': np.float64(-4.36204926670265e-05),
#  'std': np.float64(0.053476347507460366),
#  'min': np.float64(-0.3250732),
#  'max': np.float64(0.2915039)}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Rewrite in the following cell, the function <tt>get_distribution_features(signal)->dict</tt> so that is also computes the kurtosis (moment of order 4), the skew (measure of the asymmetry of the proba. distrib.) available in the <tt>scipy.stats</tt> module and the 25%, 50% and 75% percentiles.</p>
# </div>

# %%
from scipy.stats import skew, kurtosis

def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()  
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max() 
    res_dict["skew"] = skew(signal)
    res_dict["kurtosis"] = kurtosis(signal)
    res_dict["25%"] = np.percentile(signal, 25)
    res_dict["50%"] = np.percentile(signal, 50)
    res_dict["75%"] = np.percentile(signal, 75)   
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': np.float64(-4.36204926670265e-05),
#  'std': np.float64(0.053476347507460366),
#  'min': np.float64(-0.3250732),
#  'max': np.float64(0.2915039),
#  'skew': np.float64(0.28696295903662516),
#  'kurtosis': np.float64(4.395775251359628),
#  '25%': np.float64(-0.02713013),
#  '50%': np.float64(-0.0006103516),
#  '75%': np.float64(0.02511597)}

# %% [markdown]
# ### Autocorrelation
#
# For a signal $x\in\mathbb{R}^N$ with $N$ samples, the autocorrelation with lag $m$ is defined as follows:
#
# $$
# \hat{\gamma}[m] := \frac{1}{N-|m|} \sum_{n=0}^{N -|m|-1} x[n]x[n+m].
# $$
#
# Note that in practice, peaks observed in the autocorrelation function correspond to repetitions in the signal, and therefore reveal its underlying periodicity.

# %% [markdown]
# Let us plot the autocorrelation of a sound signal.

# %%
from statsmodels.tsa.stattools import acf
from scipy.signal import find_peaks
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(acf(signal, nlags=200, fft=True), ".-")
ax.axhline(0, ls="--", color="k")
ax.set_title('Autocorrelation')
ax.set_xlabel('Lags')
ax.set_ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>We would like to compute the largest positive and negative autocorrelation peaks (excluding the trivial one at lag 0), together with their associated lags in Hz. How can you convert a lag expressed in number of samples into a lag expressed in Hz?</p>
# </div>

# %%
def samples_to_hz(lag_in_samples, FREQUENCY):
    return FREQUENCY / lag_in_samples

# %% [markdown]
# why?

# %% [markdown]
# The autocorrelation features retained in the end consist of the full set of autocorrelation values, together with the amplitudes of the first negative and positive peaks and their corresponding lags.
#
# Compute the autocorrelation features.

# %%
def get_autocorr_features(signal: np.ndarray, n_lags: int = 200) -> dict:
    auto_corr = acf(signal, nlags=n_lags, fft=True)
    res_dict = dict()
    for lag, auto_corr_value in enumerate(auto_corr):
        res_dict[f"autocorrelation_{lag}_lag"] = auto_corr_value

    local_max, local_argmax = get_largest_local_max(auto_corr[1:], order=10)
    local_argmax += 1  # to account for the lag=0 removed before
    local_min, local_argmin = get_largest_local_max(-auto_corr[1:], order=10)
    local_min = -local_min
    local_argmin += 1  # to account for the lag=0 removed before
    res_dict["largest_local_max_autocorrelation"] = local_max
    res_dict["lag_largest_local_max_autocorrelation_Hz"] = samples_to_hz(local_argmax, FREQUENCY)
    res_dict["largest_local_min_autocorrelation"] = local_min
    res_dict["lag_largest_local_min_autocorrelation_Hz"] = samples_to_hz(local_argmin, FREQUENCY)
    return res_dict

# %%
get_autocorr_features(signal, n_lags=100)
# Out:
# {'autocorrelation_0_lag': np.float64(1.0),
#  'autocorrelation_1_lag': np.float64(0.9878346636837038),
#  'autocorrelation_2_lag': np.float64(0.9539436420458182),
#  'autocorrelation_3_lag': np.float64(0.9019015664004297),
#  'autocorrelation_4_lag': np.float64(0.8371394434711026),
#  'autocorrelation_5_lag': np.float64(0.7642879203951046),
#  'autocorrelation_6_lag': np.float64(0.6869953069390051),
#  'autocorrelation_7_lag': np.float64(0.6077263361362768),
#  'autocorrelation_8_lag': np.float64(0.5278428777248149),
#  'autocorrelation_9_lag': np.float64(0.44807529893529446),
#  'autocorrelation_10_lag': np.float64(0.3687853142820053),
#  'autocorrelation_11_lag': np.float64(0.29043191283938363),
#  'autocorrelation_12_lag': np.float64(0.2135843409306105),
#  'autocorrelation_13_lag': np.float64(0.1391579881199314),
#  'autocorrelation_14_lag': np.float64(0.06811555363757311),
#  'autocorrelation_15_lag': np.float64(0.0015317560749448663),
#  'autocorrelation_16_lag': np.float64(-0.05982668166177404),
#  'autocorrelation_17_lag': np.float64(-0.11537747797593947),
#  'autocorrelation_18_lag': np.float64(-0.1650154245069034),
#  'autocorrelation_19_lag': np.float64(-0.2087973563131599),
#  'autocorrelation_20_lag': np.float64(-0.24706403734001328),
#  'autocorrelation_21_lag': np.float64(-0.2800871788450011),
#  'autocorrelation_22_lag': np.float64(-0.3081908758365509),
#  'autocorrelation_23_lag': np.float64(-0.3315089007310145),
#  'autocorrelation_24_lag': np.float64(-0.3501835950704428),
#  'autocorrelation_25_lag': np.float64(-0.3642108428221866),
#  'autocorrelation_26_lag': np.float64(-0.373667316345464),
#  'autocorrelation_27_lag': np.float64(-0.37863548552537973),
#  'autocorrelation_28_lag': np.float64(-0.37926049538893536),
#  'autocorrelation_29_lag': np.float64(-0.37576001516976526),
#  'autocorrelation_30_lag': np.float64(-0.36832282777892117),
#  'autocorrelation_31_lag': np.float64(-0.35712048030610904),
#  'autocorrelation_32_lag': np.float64(-0.3423271779094116),
#  'autocorrelation_33_lag': np.float64(-0.3241544612915392),
#  'autocorrelation_34_lag': np.float64(-0.30288790360860873),
#  'autocorrelation_35_lag': np.float64(-0.2789734799408918),
#  'autocorrelation_36_lag': np.float64(-0.25291372258109374),
#  'autocorrelation_37_lag': np.float64(-0.22533812330754216),
#  'autocorrelation_38_lag': np.float64(-0.19684843697856055),
#  'autocorrelation_39_lag': np.float64(-0.168023099095667),
#  'autocorrelation_40_lag': np.float64(-0.1394378205214003),
#  'autocorrelation_41_lag': np.float64(-0.11156357029400864),
#  'autocorrelation_42_lag': np.float64(-0.08484822155672082),
#  'autocorrelation_43_lag': np.float64(-0.059649290884909396),
#  'autocorrelation_44_lag': np.float64(-0.03633053283319132),
#  'autocorrelation_45_lag': np.float64(-0.015222023575950584),
#  'autocorrelation_46_lag': np.float64(0.0033494745622185593),
#  'autocorrelation_47_lag': np.float64(0.01913967314261184),
#  'autocorrelation_48_lag': np.float64(0.03194172381216762),
#  'autocorrelation_49_lag': np.float64(0.04167155608101481),
#  'autocorrelation_50_lag': np.float64(0.04831299520036119),
#  'autocorrelation_51_lag': np.float64(0.051931058715674806),
#  'autocorrelation_52_lag': np.float64(0.05259702058107733),
#  'autocorrelation_53_lag': np.float64(0.050403099453469),
#  'autocorrelation_54_lag': np.float64(0.04543152072644382),
#  'autocorrelation_55_lag': np.float64(0.03771004721405502),
#  'autocorrelation_56_lag': np.float64(0.02732502675621452),
#  'autocorrelation_57_lag': np.float64(0.014351913207245236),
#  'autocorrelation_58_lag': np.float64(-0.0010188425296251099),
#  'autocorrelation_59_lag': np.float64(-0.01853244782758934),
#  'autocorrelation_60_lag': np.float64(-0.03780856118060252),
#  'autocorrelation_61_lag': np.float64(-0.0583781246767879),
#  'autocorrelation_62_lag': np.float64(-0.07971126121316431),
#  'autocorrelation_63_lag': np.float64(-0.10122704097837275),
#  'autocorrelation_64_lag': np.float64(-0.12237505824634415),
#  'autocorrelation_65_lag': np.float64(-0.1426486688614802),
#  'autocorrelation_66_lag': np.float64(-0.1616164464932969),
#  'autocorrelation_67_lag': np.float64(-0.178962678568969),
#  'autocorrelation_68_lag': np.float64(-0.1944102132644251),
#  'autocorrelation_69_lag': np.float64(-0.20779568783360688),
#  'autocorrelation_70_lag': np.float64(-0.21896560608272636),
#  'autocorrelation_71_lag': np.float64(-0.22780766284055096),
#  'autocorrelation_72_lag': np.float64(-0.23423609800987297),
#  'autocorrelation_73_lag': np.float64(-0.23817406508057903),
#  'autocorrelation_74_lag': np.float64(-0.23959055515438923),
#  'autocorrelation_75_lag': np.float64(-0.23845645517925856),
#  'autocorrelation_76_lag': np.float64(-0.23480331114590977),
#  'autocorrelation_77_lag': np.float64(-0.22865376957421005),
#  'autocorrelation_78_lag': np.float64(-0.2201136698177426),
#  'autocorrelation_79_lag': np.float64(-0.20924783552593149),
#  'autocorrelation_80_lag': np.float64(-0.19622041017669214),
#  'autocorrelation_81_lag': np.float64(-0.181165717983397),
#  'autocorrelation_82_lag': np.float64(-0.16429517066410426),
#  'autocorrelation_83_lag': np.float64(-0.14581458279684492),
#  'autocorrelation_84_lag': np.float64(-0.12596322910833258),
#  'autocorrelation_85_lag': np.float64(-0.1050060131262428),
#  'autocorrelation_86_lag': np.float64(-0.08319860396399148),
#  'autocorrelation_87_lag': np.float64(-0.06083801272293343),
#  'autocorrelation_88_lag': np.float64(-0.03824515024703428),
#  'autocorrelation_89_lag': np.float64(-0.01575305517288249),
#  'autocorrelation_90_lag': np.float64(0.006299229785178285),
#  'autocorrelation_91_lag': np.float64(0.027554901388277396),
#  'autocorrelation_92_lag': np.float64(0.04769058796728643),
#  'autocorrelation_93_lag': np.float64(0.06636662193133662),
#  'autocorrelation_94_lag': np.float64(0.08331673021314656),
#  'autocorrelation_95_lag': np.float64(0.09826578021067983),
#  'autocorrelation_96_lag': np.float64(0.11099911365235116),
#  'autocorrelation_97_lag': np.float64(0.1213174013316438),
#  'autocorrelation_98_lag': np.float64(0.12907567451385127),
#  'autocorrelation_99_lag': np.float64(0.1341928000789746),
#  'autocorrelation_100_lag': np.float64(0.13666303526893825),
#  'largest_local_max_autocorrelation': np.float64(0.05259702058107733),
#  'lag_largest_local_max_autocorrelation_Hz': np.float64(38.46153846153846),
#  'largest_local_min_autocorrelation': np.float64(-0.37926049538893536),
#  'lag_largest_local_min_autocorrelation_Hz': np.float64(71.42857142857143)}

# %% [markdown]
# ## 3.b Spectral features

# %% [markdown]
# Using the Discrete Fourier Transform (DFT), we can identify which frequencies are present in the signal and their associated amplitudes.
#
# For a signal $x\in\mathbb{R}^N$ with $N$ samples, the $k$-th discrete fourier coefficient is defined as follows:
#
# $$
# X[k] = \sum_{n=0}^{N-1}x[n]e^{-j2\pi\frac{kn}{N}}.
# $$
# $X[k]$ corresponds to the DFT for the physical frequency
# $$f[k]=k\frac{F_s}{N}$$
#
#
# Plot the Fourier coefficients of a signal (y=absolute value, x=frequency) using `rfft()` and `rfftfreq()`.

# %%
from scipy.fft import rfft, rfftfreq
fourier = abs(rfft(signal)) ** 2
freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)

fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(freqs, fourier)
ax.set_xlabel("Frequency (Hz)")
_ = ax.set_ylabel("Fourier coefficient")

# %% [markdown]
# Compute the spectral features.

# %%
def get_fourier_features(signal: np.ndarray, n_bins: int = 100) -> dict:
    """The signal is assumed to be centered and scaled to unit variance."""
    n_samples = signal.shape[0]
    fourier = abs(rfft(signal))
    freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)
    res_dict = dict()

    freq_bins = np.linspace(0, FREQUENCY / 2, n_bins + 1)
    for f_min, f_max in pairwise(freq_bins):
        keep = (f_min <= freqs) & (freqs < f_max)
        res_dict[f"fourier_{f_min:.0f}-{f_max:.0f}_Hz"] = np.log(
            np.sum(fourier[keep] ** 2)
        )
    return res_dict

# %%
get_fourier_features(signal, n_bins=10)
# Out:
# {'fourier_0-100_Hz': np.float64(13.062805200766368),
#  'fourier_100-200_Hz': np.float64(9.789782046195757),
#  'fourier_200-300_Hz': np.float64(7.474775836054673),
#  'fourier_300-400_Hz': np.float64(5.042830727182429),
#  'fourier_400-500_Hz': np.float64(3.271908511560872),
#  'fourier_500-600_Hz': np.float64(2.034724789695901),
#  'fourier_600-700_Hz': np.float64(2.072603298867694),
#  'fourier_700-800_Hz': np.float64(2.6515556177815025),
#  'fourier_800-900_Hz': np.float64(2.993208438886879),
#  'fourier_900-1000_Hz': np.float64(3.172705345844466)}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>The frequency features are not scaled. If the signal is normalized, do we need to?</p>
# </div>

# %% [markdown]
# NO, from Plancherel, if we normalise one we normalize the other

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> We have used regularly spaced frequency bins. What would be a better approach? </p>
#
# </div>

# %% [markdown]
# Log-espaces

# %% [markdown]
# ## Concatenate all features

# %% [markdown]
# In the following cell, we write a function `get_features(signal: np.ndarray) -> dict` that computes all features from above.

# %%
def get_features(signal: np.ndarray) -> dict:
    res_dict = dict()

    # stats
    res_dict.update(get_distribution_features(signal))

    # spectral
    signal -= signal.mean()
    signal /= signal.std()
    res_dict.update(get_fourier_features(signal, n_bins=50))

    # autocorrelation
    res_dict.update(get_autocorr_features(signal, n_lags=200))

    return res_dict

# %%
get_features(signal)
# Out:
# {'mean': np.float64(-4.36204926670265e-05),
#  'std': np.float64(0.053476347507460366),
#  'min': np.float64(-0.3250732),
#  'max': np.float64(0.2915039),
#  'skew': np.float64(0.28696295903662516),
#  'kurtosis': np.float64(4.395775251359628),
#  '25%': np.float64(-0.02713013),
#  '50%': np.float64(-0.0006103516),
#  '75%': np.float64(0.02511597),
#  'fourier_0-20_Hz': np.float64(17.425511109475327),
#  'fourier_20-40_Hz': np.float64(18.08989281619167),
#  'fourier_40-60_Hz': np.float64(17.489366231711315),
#  'fourier_60-80_Hz': np.float64(16.265620325645486),
#  'fourier_80-100_Hz': np.float64(15.412438705688363),
#  'fourier_100-120_Hz': np.float64(14.740121990157501),
#  'fourier_120-140_Hz': np.float64(14.11903917348016),
#  'fourier_140-160_Hz': np.float64(13.870068979262031),
#  'fourier_160-180_Hz': np.float64(13.582886659613838),
#  'fourier_180-200_Hz': np.float64(13.157674451752792),
#  'fourier_200-220_Hz': np.float64(12.671549166315039),
#  'fourier_220-240_Hz': np.float64(11.825080871850867),
#  'fourier_240-260_Hz': np.float64(11.255058694087516),
#  'fourier_260-280_Hz': np.float64(10.84329864883104),
#  'fourier_280-300_Hz': np.float64(10.39955950521556),
#  'fourier_300-320_Hz': np.float64(9.890567601073455),
#  'fourier_320-340_Hz': np.float64(9.58705281499147),
#  'fourier_340-360_Hz': np.float64(9.188995074055711),
#  'fourier_360-380_Hz': np.float64(8.645898685416842),
#  'fourier_380-400_Hz': np.float64(8.383709665435289),
#  'fourier_400-420_Hz': np.float64(8.051003827274839),
#  'fourier_420-440_Hz': np.float64(7.731607048953479),
#  'fourier_440-460_Hz': np.float64(7.450347500206702),
#  'fourier_460-480_Hz': np.float64(7.014887152886691),
#  'fourier_480-500_Hz': np.float64(6.875749029206018),
#  'fourier_500-520_Hz': np.float64(6.568951791047229),
#  'fourier_520-540_Hz': np.float64(6.193628207989099),
#  'fourier_540-560_Hz': np.float64(6.436477831955527),
#  'fourier_560-580_Hz': np.float64(6.010109654072031),
#  'fourier_580-600_Hz': np.float64(6.089417460480802),
#  'fourier_600-620_Hz': np.float64(6.071361635325673),
#  'fourier_620-640_Hz': np.float64(6.300262020106503),
#  'fourier_640-660_Hz': np.float64(6.234504126007418),
#  'fourier_660-680_Hz': np.float64(6.428478940550235),
#  'fourier_680-700_Hz': np.float64(6.508990462396064),
#  'fourier_700-720_Hz': np.float64(6.8466532736755505),
#  'fourier_720-740_Hz': np.float64(6.652063380023947),
#  'fourier_740-760_Hz': np.float64(6.7625636237651365),
#  'fourier_760-780_Hz': np.float64(7.058395647354166),
#  'fourier_780-800_Hz': np.float64(7.102180136547861),
#  'fourier_800-820_Hz': np.float64(7.053912666023322),
#  'fourier_820-840_Hz': np.float64(7.210071570949586),
#  'fourier_840-860_Hz': np.float64(7.281311046856823),
#  'fourier_860-880_Hz': np.float64(7.291408810734029),
#  'fourier_880-900_Hz': np.float64(7.342887774206716),
#  'fourier_900-920_Hz': np.float64(7.395765109126665),
#  'fourier_920-940_Hz': np.float64(7.687514992541044),
#  'fourier_940-960_Hz': np.float64(7.582547372242515),
#  'fourier_960-980_Hz': np.float64(7.3493322942407415),
#  'fourier_980-1000_Hz': np.float64(6.926441922399655),
#  'autocorrelation_0_lag': np.float64(1.0),
#  'autocorrelation_1_lag': np.float64(0.9878346636837039),
#  'autocorrelation_2_lag': np.float64(0.9539436420458183),
#  'autocorrelation_3_lag': np.float64(0.9019015664004298),
#  'autocorrelation_4_lag': np.float64(0.8371394434711027),
#  'autocorrelation_5_lag': np.float64(0.7642879203951048),
#  'autocorrelation_6_lag': np.float64(0.6869953069390051),
#  'autocorrelation_7_lag': np.float64(0.607726336136277),
#  'autocorrelation_8_lag': np.float64(0.527842877724815),
#  'autocorrelation_9_lag': np.float64(0.4480752989352946),
#  'autocorrelation_10_lag': np.float64(0.3687853142820053),
#  'autocorrelation_11_lag': np.float64(0.29043191283938363),
#  'autocorrelation_12_lag': np.float64(0.21358434093061054),
#  'autocorrelation_13_lag': np.float64(0.13915798811993144),
#  'autocorrelation_14_lag': np.float64(0.06811555363757313),
#  'autocorrelation_15_lag': np.float64(0.0015317560749448813),
#  'autocorrelation_16_lag': np.float64(-0.05982668166177402),
#  'autocorrelation_17_lag': np.float64(-0.11537747797593949),
#  'autocorrelation_18_lag': np.float64(-0.16501542450690337),
#  'autocorrelation_19_lag': np.float64(-0.20879735631315996),
#  'autocorrelation_20_lag': np.float64(-0.24706403734001334),
#  'autocorrelation_21_lag': np.float64(-0.2800871788450012),
#  'autocorrelation_22_lag': np.float64(-0.30819087583655086),
#  'autocorrelation_23_lag': np.float64(-0.3315089007310145),
#  'autocorrelation_24_lag': np.float64(-0.35018359507044283),
#  'autocorrelation_25_lag': np.float64(-0.3642108428221866),
#  'autocorrelation_26_lag': np.float64(-0.37366731634546413),
#  'autocorrelation_27_lag': np.float64(-0.3786354855253798),
#  'autocorrelation_28_lag': np.float64(-0.3792604953889355),
#  'autocorrelation_29_lag': np.float64(-0.3757600151697653),
#  'autocorrelation_30_lag': np.float64(-0.3683228277789211),
#  'autocorrelation_31_lag': np.float64(-0.35712048030610916),
#  'autocorrelation_32_lag': np.float64(-0.34232717790941164),
#  'autocorrelation_33_lag': np.float64(-0.3241544612915392),
#  'autocorrelation_34_lag': np.float64(-0.3028879036086087),
#  'autocorrelation_35_lag': np.float64(-0.27897347994089183),
#  'autocorrelation_36_lag': np.float64(-0.25291372258109374),
#  'autocorrelation_37_lag': np.float64(-0.22533812330754213),
#  'autocorrelation_38_lag': np.float64(-0.19684843697856058),
#  'autocorrelation_39_lag': np.float64(-0.16802309909566707),
#  'autocorrelation_40_lag': np.float64(-0.13943782052140027),
#  'autocorrelation_41_lag': np.float64(-0.11156357029400865),
#  'autocorrelation_42_lag': np.float64(-0.08484822155672081),
#  'autocorrelation_43_lag': np.float64(-0.059649290884909424),
#  'autocorrelation_44_lag': np.float64(-0.03633053283319133),
#  'autocorrelation_45_lag': np.float64(-0.015222023575950596),
#  'autocorrelation_46_lag': np.float64(0.003349474562218545),
#  'autocorrelation_47_lag': np.float64(0.019139673142611835),
#  'autocorrelation_48_lag': np.float64(0.03194172381216762),
#  'autocorrelation_49_lag': np.float64(0.0416715560810148),
#  'autocorrelation_50_lag': np.float64(0.04831299520036119),
#  'autocorrelation_51_lag': np.float64(0.0519310587156748),
#  'autocorrelation_52_lag': np.float64(0.052597020581077326),
#  'autocorrelation_53_lag': np.float64(0.05040309945346899),
#  'autocorrelation_54_lag': np.float64(0.045431520726443804),
#  'autocorrelation_55_lag': np.float64(0.03771004721405501),
#  'autocorrelation_56_lag': np.float64(0.027325026756214517),
#  'autocorrelation_57_lag': np.float64(0.014351913207245224),
#  'autocorrelation_58_lag': np.float64(-0.001018842529625125),
#  'autocorrelation_59_lag': np.float64(-0.01853244782758936),
#  'autocorrelation_60_lag': np.float64(-0.03780856118060256),
#  'autocorrelation_61_lag': np.float64(-0.058378124676787914),
#  'autocorrelation_62_lag': np.float64(-0.07971126121316435),
#  'autocorrelation_63_lag': np.float64(-0.10122704097837278),
#  'autocorrelation_64_lag': np.float64(-0.1223750582463442),
#  'autocorrelation_65_lag': np.float64(-0.14264866886148023),
#  'autocorrelation_66_lag': np.float64(-0.1616164464932969),
#  'autocorrelation_67_lag': np.float64(-0.17896267856896902),
#  'autocorrelation_68_lag': np.float64(-0.19441021326442512),
#  'autocorrelation_69_lag': np.float64(-0.2077956878336069),
#  'autocorrelation_70_lag': np.float64(-0.21896560608272644),
#  'autocorrelation_71_lag': np.float64(-0.22780766284055104),
#  'autocorrelation_72_lag': np.float64(-0.23423609800987302),
#  'autocorrelation_73_lag': np.float64(-0.23817406508057903),
#  'autocorrelation_74_lag': np.float64(-0.2395905551543893),
#  'autocorrelation_75_lag': np.float64(-0.23845645517925865),
#  'autocorrelation_76_lag': np.float64(-0.23480331114590985),
#  'autocorrelation_77_lag': np.float64(-0.22865376957421008),
#  'autocorrelation_78_lag': np.float64(-0.22011366981774266),
#  'autocorrelation_79_lag': np.float64(-0.20924783552593157),
#  'autocorrelation_80_lag': np.float64(-0.19622041017669217),
#  'autocorrelation_81_lag': np.float64(-0.181165717983397),
#  'autocorrelation_82_lag': np.float64(-0.16429517066410432),
#  'autocorrelation_83_lag': np.float64(-0.1458145827968449),
#  'autocorrelation_84_lag': np.float64(-0.1259632291083326),
#  'autocorrelation_85_lag': np.float64(-0.10500601312624282),
#  'autocorrelation_86_lag': np.float64(-0.08319860396399147),
#  'autocorrelation_87_lag': np.float64(-0.06083801272293344),
#  'autocorrelation_88_lag': np.float64(-0.03824515024703428),
#  'autocorrelation_89_lag': np.float64(-0.015753055172882488),
#  'autocorrelation_90_lag': np.float64(0.006299229785178297),
#  'autocorrelation_91_lag': np.float64(0.02755490138827742),
#  'autocorrelation_92_lag': np.float64(0.047690587967286445),
#  'autocorrelation_93_lag': np.float64(0.06636662193133665),
#  'autocorrelation_94_lag': np.float64(0.08331673021314656),
#  'autocorrelation_95_lag': np.float64(0.09826578021067987),
#  'autocorrelation_96_lag': np.float64(0.11099911365235117),
#  'autocorrelation_97_lag': np.float64(0.12131740133164384),
#  'autocorrelation_98_lag': np.float64(0.12907567451385127),
#  'autocorrelation_99_lag': np.float64(0.13419280007897463),
#  'autocorrelation_100_lag': np.float64(0.13666303526893825),
#  'autocorrelation_101_lag': np.float64(0.13657729074790673),
#  'autocorrelation_102_lag': np.float64(0.13406201739160936),
#  'autocorrelation_103_lag': np.float64(0.1293617403281256),
#  'autocorrelation_104_lag': np.float64(0.12270916916858289),
#  'autocorrelation_105_lag': np.float64(0.11444500934072942),
#  'autocorrelation_106_lag': np.float64(0.10486749702664583),
#  'autocorrelation_107_lag': np.float64(0.09433152677701631),
#  'autocorrelation_108_lag': np.float64(0.08313246202596061),
#  'autocorrelation_109_lag': np.float64(0.0715963018310512),
#  'autocorrelation_110_lag': np.float64(0.05998600287668385),
#  'autocorrelation_111_lag': np.float64(0.04859828514513373),
#  'autocorrelation_112_lag': np.float64(0.037685648957003985),
#  'autocorrelation_113_lag': np.float64(0.027478085957334614),
#  'autocorrelation_114_lag': np.float64(0.018168172267147304),
#  'autocorrelation_115_lag': np.float64(0.009909665968623095),
#  'autocorrelation_116_lag': np.float64(0.0028217417336435045),
#  'autocorrelation_117_lag': np.float64(-0.0030046640031455517),
#  'autocorrelation_118_lag': np.float64(-0.0075039973478176515),
#  'autocorrelation_119_lag': np.float64(-0.010625015895813139),
#  'autocorrelation_120_lag': np.float64(-0.012325415669013531),
#  'autocorrelation_121_lag': np.float64(-0.0125856804336185),
#  'autocorrelation_122_lag': np.float64(-0.011353917397044118),
#  'autocorrelation_123_lag': np.float64(-0.008640340111281907),
#  'autocorrelation_124_lag': np.float64(-0.004444002195379164),
#  'autocorrelation_125_lag': np.float64(0.0011459716970619873),
#  'autocorrelation_126_lag': np.float64(0.008024276491448426),
#  'autocorrelation_127_lag': np.float64(0.0160074135371302),
#  'autocorrelation_128_lag': np.float64(0.024900679680806375),
#  'autocorrelation_129_lag': np.float64(0.034467441568183314),
#  'autocorrelation_130_lag': np.float64(0.04449255071153026),
#  'autocorrelation_131_lag': np.float64(0.05472498158446836),
#  'autocorrelation_132_lag': np.float64(0.06492835295131279),
#  'autocorrelation_133_lag': np.float64(0.07486023583017928),
#  'autocorrelation_134_lag': np.float64(0.08425334108052744),
#  'autocorrelation_135_lag': np.float64(0.09286967368238692),
#  'autocorrelation_136_lag': np.float64(0.10044944218344985),
#  'autocorrelation_137_lag': np.float64(0.10680583073314104),
#  'autocorrelation_138_lag': np.float64(0.1117748201731784),
#  'autocorrelation_139_lag': np.float64(0.11528137627123722),
#  'autocorrelation_140_lag': np.float64(0.11728901333065142),
#  'autocorrelation_141_lag': np.float64(0.11784216552115563),
#  'autocorrelation_142_lag': np.float64(0.11700421950255165),
#  'autocorrelation_143_lag': np.float64(0.11491118835484479),
#  'autocorrelation_144_lag': np.float64(0.11171929631272941),
#  'autocorrelation_145_lag': np.float64(0.10761602163184755),
#  'autocorrelation_146_lag': np.float64(0.10282301454858421),
#  'autocorrelation_147_lag': np.float64(0.0975356644159605),
#  'autocorrelation_148_lag': np.float64(0.09199804218514013),
#  'autocorrelation_149_lag': np.float64(0.08632531973089493),
#  'autocorrelation_150_lag': np.float64(0.08062661974764909),
#  'autocorrelation_151_lag': np.float64(0.07486421274036378),
#  'autocorrelation_152_lag': np.float64(0.06896410795034975),
#  'autocorrelation_153_lag': np.float64(0.06277549981455176),
#  'autocorrelation_154_lag': np.float64(0.05615398478058582),
#  'autocorrelation_155_lag': np.float64(0.048999788209914075),
#  'autocorrelation_156_lag': np.float64(0.041299761676451024),
#  'autocorrelation_157_lag': np.float64(0.03311816889647373),
#  'autocorrelation_158_lag': np.float64(0.024602284789287502),
#  'autocorrelation_159_lag': np.float64(0.015918176805788692),
#  'autocorrelation_160_lag': np.float64(0.00725008312055939),
#  'autocorrelation_161_lag': np.float64(-0.0012557564756580687),
#  'autocorrelation_162_lag': np.float64(-0.009470837929566659),
#  'autocorrelation_163_lag': np.float64(-0.017312281389553694),
#  'autocorrelation_164_lag': np.float64(-0.02471898558515841),
#  'autocorrelation_165_lag': np.float64(-0.03163980952854062),
#  'autocorrelation_166_lag': np.float64(-0.038039145409510824),
#  'autocorrelation_167_lag': np.float64(-0.04387226238877253),
#  'autocorrelation_168_lag': np.float64(-0.049152615689111286),
#  'autocorrelation_169_lag': np.float64(-0.053855702547211434),
#  'autocorrelation_170_lag': np.float64(-0.057998642695400345),
#  'autocorrelation_171_lag': np.float64(-0.06154046109145072),
#  'autocorrelation_172_lag': np.float64(-0.06444174399646961),
#  'autocorrelation_173_lag': np.float64(-0.06664744044733492),
#  'autocorrelation_174_lag': np.float64(-0.06814523313389213),
#  'autocorrelation_175_lag': np.float64(-0.06894024196156347),
#  'autocorrelation_176_lag': np.float64(-0.06906363720103496),
#  'autocorrelation_177_lag': np.float64(-0.06852643160497243),
#  'autocorrelation_178_lag': np.float64(-0.06738488715247379),
#  'autocorrelation_179_lag': np.float64(-0.06568176286236402),
#  'autocorrelation_180_lag': np.float64(-0.06348874622492767),
#  'autocorrelation_181_lag': np.float64(-0.06084883637887209),
#  'autocorrelation_182_lag': np.float64(-0.05781117175975187),
#  'autocorrelation_183_lag': np.float64(-0.05440202631090682),
#  'autocorrelation_184_lag': np.float64(-0.050665634337426636),
#  'autocorrelation_185_lag': np.float64(-0.04664854971179223),
#  'autocorrelation_186_lag': np.float64(-0.04242046529204622),
#  'autocorrelation_187_lag': np.float64(-0.038056272137780484),
#  'autocorrelation_188_lag': np.float64(-0.033614955430792695),
#  'autocorrelation_189_lag': np.float64(-0.029206409654693382),
#  'autocorrelation_190_lag': np.float64(-0.02490074557943493),
#  'autocorrelation_191_lag': np.float64(-0.020824782404927904),
#  'autocorrelation_192_lag': np.float64(-0.017019819373232558),
#  'autocorrelation_193_lag': np.float64(-0.013567979935249004),
#  'autocorrelation_194_lag': np.float64(-0.010461701681867197),
#  'autocorrelation_195_lag': np.float64(-0.007693335957093076),
#  'autocorrelation_196_lag': np.float64(-0.005201396760946958),
#  'autocorrelation_197_lag': np.float64(-0.00291535638604588),
#  'autocorrelation_198_lag': np.float64(-0.000771928517145765),
#  'autocorrelation_199_lag': np.float64(0.0012826050908842583),
#  'autocorrelation_200_lag': np.float64(0.003266911420446221),
#  'largest_local_max_autocorrelation': np.float64(0.13666303526893825),
#  'lag_largest_local_max_autocorrelation_Hz': np.float64(20.0),
#  'largest_local_min_autocorrelation': np.float64(-0.3792604953889355),
#  'lag_largest_local_min_autocorrelation_Hz': np.float64(71.42857142857143)}

# %% [markdown]
# Compute all features over the data set.

# %%
all_features = pd.DataFrame(
    [get_features(signal) for signal in X]
)

# %%
all_features.head()
# Out:
#            mean       std       min       max      skew   kurtosis       25%  \
# 0  9.202928e-18  1.000000 -6.078006  5.451897  0.286963   4.395775 -0.506514
# 1 -2.638213e-05  0.021232 -0.109467  0.139496  0.389185   4.207598 -0.011505
# 2 -6.927476e-05  0.034245 -0.253387  0.291596  1.362185  22.093219 -0.007721
# 3 -2.619600e-05  0.075533 -0.440369  0.644653  1.424710  15.069250 -0.020012
# 4 -2.100810e-05  0.126608 -1.000000  0.999969  0.238795  20.218365 -0.017639
#
#         50%       75%  fourier_0-20_Hz  ...  autocorrelation_195_lag  \
# 0 -0.010598  0.470481        17.425511  ...                -0.007693
# 1 -0.000244  0.010864        17.947738  ...                 0.139093
# 2 -0.000031  0.007477        15.761979  ...                 0.004491
# 3 -0.000275  0.018646        15.773631  ...                 0.011920
# 4  0.000275  0.016685        15.738893  ...                 0.023134
#
#    autocorrelation_196_lag  autocorrelation_197_lag  autocorrelation_198_lag  \
# 0                -0.005201                -0.002915                -0.000772
# 1                 0.134445                 0.129681                 0.124822
# 2                 0.002655                 0.000759                -0.001193
# 3                 0.015518                 0.018804                 0.021765
# 4                 0.022036                 0.020845                 0.019556
#
#    autocorrelation_199_lag  autocorrelation_200_lag  \
# 0                 0.001283                 0.003267
# 1                 0.119951                 0.115106
# 2                -0.003117                -0.005015
# 3                 0.024399                 0.026711
# 4                 0.018152                 0.016617
#
#    largest_local_max_autocorrelation  \
# 0                           0.136663
# 1                           0.169397
# 2                           0.113092
# 3                           0.159935
# 4                           0.283012
#
#    lag_largest_local_max_autocorrelation_Hz  \
# 0                                 20.000000
# 1                                 10.869565
# 2                                 40.816327
# 3                                 30.769231
# 4                                 37.037037
#
#    largest_local_min_autocorrelation  lag_largest_local_min_autocorrelation_Hz
# 0                          -0.379260                                 71.428571
# 1                          -0.275819                                 43.478261
# 2                          -0.542523                                 95.238095
# 3                          -0.451949                                 95.238095
# 4                          -0.571900                                 86.956522
#
# [5 rows x 264 columns]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ### Unsupervised selection
#
# #### Sanity checks
#
# **Low variance threshold**

# %%
fig, ax = plt.subplots(figsize=(15, 5))
all_features.std().sort_values().plot(ax=ax)

# change the height of the horizontal line here
ax.axhline(0.1, ls="--", color="k")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Choose a variance threshold (name it <tt>variance_threshold</tt>).</p>
# </div>

# %%
variance_threshold = 0.1

# %% [markdown]
# Be careful when dropping low variance features, they might still be informative. Quickly check that it makes sense to drop them.

# %%
low_variance_features = all_features.std() < variance_threshold
low_variance_features = low_variance_features[
    low_variance_features
].index.to_numpy()
print(f"There are {len(low_variance_features)} features to drop.")
print(low_variance_features)
# Out:
# There are 122 features to drop.
# ['mean' 'std' '25%' '50%' '75%' 'autocorrelation_0_lag'
#  'autocorrelation_1_lag' 'autocorrelation_2_lag' 'autocorrelation_3_lag'
#  'autocorrelation_4_lag' 'autocorrelation_89_lag' 'autocorrelation_90_lag'
#  'autocorrelation_91_lag' 'autocorrelation_92_lag'
#  'autocorrelation_93_lag' 'autocorrelation_94_lag'
#  'autocorrelation_95_lag' 'autocorrelation_96_lag'
#  'autocorrelation_97_lag' 'autocorrelation_98_lag'
#  'autocorrelation_99_lag' 'autocorrelation_100_lag'
#  'autocorrelation_101_lag' 'autocorrelation_102_lag'
#  'autocorrelation_103_lag' 'autocorrelation_104_lag'
#  'autocorrelation_105_lag' 'autocorrelation_106_lag'
#  'autocorrelation_107_lag' 'autocorrelation_108_lag'
#  'autocorrelation_109_lag' 'autocorrelation_110_lag'
#  'autocorrelation_111_lag' 'autocorrelation_112_lag'
#  'autocorrelation_113_lag' 'autocorrelation_114_lag'
#  'autocorrelation_115_lag' 'autocorrelation_116_lag'
#  'autocorrelation_117_lag' 'autocorrelation_118_lag'
#  'autocorrelation_119_lag' 'autocorrelation_120_lag'
#  'autocorrelation_121_lag' 'autocorrelation_122_lag'
#  'autocorrelation_123_lag' 'autocorrelation_124_lag'
#  'autocorrelation_125_lag' 'autocorrelation_126_lag'
#  'autocorrelation_127_lag' 'autocorrelation_128_lag'
#  'autocorrelation_129_lag' 'autocorrelation_130_lag'
#  'autocorrelation_131_lag' 'autocorrelation_132_lag'
#  'autocorrelation_133_lag' 'autocorrelation_134_lag'
#  'autocorrelation_135_lag' 'autocorrelation_136_lag'
#  'autocorrelation_137_lag' 'autocorrelation_138_lag'
#  'autocorrelation_139_lag' 'autocorrelation_140_lag'
#  'autocorrelation_141_lag' 'autocorrelation_142_lag'
#  'autocorrelation_143_lag' 'autocorrelation_144_lag'
#  'autocorrelation_145_lag' 'autocorrelation_146_lag'
#  'autocorrelation_147_lag' 'autocorrelation_148_lag'
#  'autocorrelation_149_lag' 'autocorrelation_150_lag'
#  'autocorrelation_151_lag' 'autocorrelation_152_lag'
#  'autocorrelation_153_lag' 'autocorrelation_154_lag'
#  'autocorrelation_155_lag' 'autocorrelation_156_lag'
#  'autocorrelation_157_lag' 'autocorrelation_158_lag'
#  'autocorrelation_159_lag' 'autocorrelation_160_lag'
#  'autocorrelation_161_lag' 'autocorrelation_162_lag'
#  'autocorrelation_163_lag' 'autocorrelation_164_lag'
#  'autocorrelation_165_lag' 'autocorrelation_166_lag'
#  'autocorrelation_167_lag' 'autocorrelation_168_lag'
#  'autocorrelation_169_lag' 'autocorrelation_170_lag'
#  'autocorrelation_171_lag' 'autocorrelation_172_lag'
#  'autocorrelation_173_lag' 'autocorrelation_174_lag'
#  'autocorrelation_175_lag' 'autocorrelation_176_lag'
#  'autocorrelation_177_lag' 'autocorrelation_178_lag'
#  'autocorrelation_179_lag' 'autocorrelation_180_lag'
#  'autocorrelation_181_lag' 'autocorrelation_182_lag'
#  'autocorrelation_183_lag' 'autocorrelation_184_lag'
#  'autocorrelation_185_lag' 'autocorrelation_186_lag'
#  'autocorrelation_187_lag' 'autocorrelation_188_lag'
#  'autocorrelation_189_lag' 'autocorrelation_190_lag'
#  'autocorrelation_191_lag' 'autocorrelation_192_lag'
#  'autocorrelation_193_lag' 'autocorrelation_194_lag'
#  'autocorrelation_195_lag' 'autocorrelation_196_lag'
#  'autocorrelation_197_lag' 'autocorrelation_198_lag'
#  'autocorrelation_199_lag' 'autocorrelation_200_lag']

# %% [markdown]
# The following cell drops the low-variance features. Only execute it when you are sure of the features you want to remove.

# %%
all_features.drop(columns=low_variance_features, inplace=True, errors="ignore")
print(f"There are {all_features.shape[1]} features left.")
# Out:
# There are 142 features left.

# %% [markdown]
# **Check outliers**

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Some features have larger variations than others: which ones are they? (Create a list <tt>features_to_check</tt>.) Show the associated histograms.</p>
# </div>

# %%
all_features.std().sort_values()
# Out:
# autocorrelation_88_lag                       0.100063
# autocorrelation_87_lag                       0.101701
# autocorrelation_86_lag                       0.103442
# autocorrelation_85_lag                       0.105822
# autocorrelation_84_lag                       0.107881
#                                               ...
# fourier_880-900_Hz                           1.980624
# fourier_840-860_Hz                           2.003963
# kurtosis                                    35.147285
# lag_largest_local_min_autocorrelation_Hz    51.448846
# lag_largest_local_max_autocorrelation_Hz    83.479428
# Length: 142, dtype: float64

# %%
features_to_check = [
    'kurtosis',
    'lag_largest_local_min_autocorrelation_Hz',
    'lag_largest_local_max_autocorrelation_Hz'
]

# %%
for feature in features_to_check:
    plt.hist(all_features[feature], bins=100)
    plt.title(feature)
    plt.plot()
    plt.show()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Check the outliers. Is there something we can do to remediate this issue?</p>
# </div>

# %%
for feature in features_to_check:
    mean_val = all_features[feature].mean()
    std_val = all_features[feature].std()
    lower = mean_val - 3 * std_val
    upper = mean_val + 3 * std_val

    # clip les valeurs en dehors des bornes
    all_features[feature] = all_features[feature].clip(lower, upper)

# %%
for feature in features_to_check:
    all_features[feature].hist(bins=30, figsize=(15, 5))
    plt.title(feature)
    plt.plot()
    plt.show()

# %% [markdown]
# **Multicollinearity**
#
# Multicollinearity degrades numerical stability and interpretability.
# Compute the correlation.
# Features with a correlation above a threshold are grouped together in a cluster.
# We then choose a single feature from each cluster.

# %%
correlation_threshold = 0.8

# %%
corr = pdist(all_features.to_numpy().T, metric="correlation")  # distance matrix
plt.imshow(squareform(corr))
plt.colorbar()
plt.title("Correlation distance matrix")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
corr_linkage = hierarchy.average(corr)
dendro = hierarchy.dendrogram(
    corr_linkage, ax=ax, color_threshold=1 - correlation_threshold
)

# %%
# compute the clusters
cluster_ids = hierarchy.fcluster(
    corr_linkage, 1 - correlation_threshold, criterion="distance"
)

# print the largest clusters
largest_cluster_ind = np.bincount(cluster_ids).argmax()
print(
    f"The largest cluster is {all_features.columns[cluster_ids==largest_cluster_ind].tolist()}."
)

# for each cluster, only keep the first feature
keep_features = list()
for cluster in np.unique(cluster_ids):
    cluster_indexes = np.where(cluster_ids == cluster)[0]
    keep_features.append(all_features.columns[cluster_indexes[0]])
# Out:
# The largest cluster is ['fourier_400-420_Hz', 'fourier_420-440_Hz', 'fourier_440-460_Hz', 'fourier_460-480_Hz', 'fourier_480-500_Hz', 'fourier_500-520_Hz', 'fourier_520-540_Hz', 'fourier_540-560_Hz', 'fourier_560-580_Hz', 'fourier_580-600_Hz', 'fourier_600-620_Hz', 'fourier_620-640_Hz', 'fourier_640-660_Hz', 'fourier_660-680_Hz', 'fourier_680-700_Hz', 'fourier_700-720_Hz', 'fourier_720-740_Hz', 'fourier_740-760_Hz', 'fourier_760-780_Hz'].

# %%
# Reduce the number of features
all_features = all_features[keep_features]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %%
all_features.shape
# Out:
# (409, 29)

# %% [markdown]
# **PCA**

# %%
all_features_centered = all_features.to_numpy()

all_features_centered -= all_features_centered.mean(axis=0)
all_features_centered /= all_features_centered.std(axis=0)


pca = PCA(n_components=2).fit(all_features_centered)

# %%
# select the 10 most important features (with highest norm).
top_features_for_pca = np.linalg.norm(pca.components_, axis=0).argsort()[-10:]

for feature_ind in top_features_for_pca:
    msg = f"{all_features.columns[feature_ind]}: {(pca.components_.T[feature_ind]**2).sum():.3f}"
    print(msg)
# Out:
# largest_local_min_autocorrelation: 0.099
# autocorrelation_41_lag: 0.100
# autocorrelation_33_lag: 0.105
# fourier_20-40_Hz: 0.106
# autocorrelation_49_lag: 0.107
# fourier_0-20_Hz: 0.119
# autocorrelation_29_lag: 0.120
# autocorrelation_13_lag: 0.125
# autocorrelation_23_lag: 0.128
# autocorrelation_19_lag: 0.129

# %%
# plot the 2D projection of the top 10 features
fig, ax = plt.subplots(figsize=(8, 8))
ax.axis("equal")
for feature_ind in top_features_for_pca:  # normaliser par la variance
    dx, dy = pca.components_.T[feature_ind]
    ax.plot([0, dx], [0, dy], label=all_features.columns[feature_ind])
ax.set_xlabel(f"PC1 ({pca.explained_variance_[0]:.1f}% of variance)")
ax.set_ylabel(f"PC1 ({pca.explained_variance_[1]:.1f}% of variance)")
_ = plt.legend()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Given a target variance threshold, determine the minimum number of principal components (n_components) required to reach or exceed this level of explained variance using PCA</p>
# </div>

# %%
variance_threshold = 0.8

# %%
variance_threshold = 0.8
pca= PCA().fit(all_features_centered)
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
plt.plot(cumulative_variance)
plt.axhline(variance_threshold, ls="--", color="k")
plt.xlabel("Number of components")
plt.ylabel("Cumulative explained variance")
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
n_components = np.argmax(cumulative_variance >= variance_threshold) + 1
n_components
# Out:
# np.int64(7)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Using the number of components (n_components) determined previously, rerun PCA with this number of components, transform the dataset into the reduced space, and then apply K-means clustering on the transformed data.</p>
# </div>

# %%
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(all_features_centered)
k=2
kmeans = KMeans(n_clusters=k, random_state=0).fit(X_pca)
labels_pred = kmeans.labels_
ari=adjusted_rand_score(labels_pred,y)
ari
# Out:
# 0.013531637804477982

# %% [markdown]
# ### Supervised selection
#
# In the supervised setting, we can further refine feature selection by taking the labels into account, keeping only the features that are most informative for the prediction task.
#
# Three main classes of methods:
#
# - **Filter methods.** We test the adequacy of the feature with the annotations, thanks to several criterion/scores (e.g. correlation).
# - **Wrapper methods.** We test the features on a supervised classification task, by trying several combinations. The best features are kept.
# - **Embedded methods.** Mixed approaches where we jointly infer the relevance of the features and classify the data (decision tree, sparse methods...)

# %% [markdown]
# **Filter methods**
#
# If a feature is highly correlated with a label, it can help achieve good classification performance.
#
# For classification tasks, we can use the ANOVA test:

# %%
labels = y
statistics, pvalues = f_oneway(
    all_features[labels == "0"], all_features[labels == "1"]
)

# %%
for ind in statistics.argsort()[::-1]:
    print(f"{all_features.columns[ind]}: {statistics[ind]:.3f}")
# Out:
# autocorrelation_49_lag: 25.535
# autocorrelation_19_lag: 20.489
# fourier_0-20_Hz: 19.804
# autocorrelation_41_lag: 17.624
# autocorrelation_13_lag: 16.306
# fourier_40-60_Hz: 15.141
# autocorrelation_23_lag: 12.337
# max: 10.814
# autocorrelation_57_lag: 10.305
# min: 9.986
# fourier_780-800_Hz: 9.453
# lag_largest_local_min_autocorrelation_Hz: 7.686
# fourier_60-80_Hz: 3.704
# fourier_80-100_Hz: 2.924
# fourier_120-140_Hz: 2.833
# autocorrelation_5_lag: 2.207
# largest_local_min_autocorrelation: 1.747
# fourier_400-420_Hz: 1.732
# autocorrelation_33_lag: 1.700
# fourier_20-40_Hz: 1.494
# autocorrelation_81_lag: 1.335
# largest_local_max_autocorrelation: 1.006
# autocorrelation_73_lag: 0.709
# autocorrelation_29_lag: 0.507
# fourier_200-220_Hz: 0.389
# lag_largest_local_max_autocorrelation_Hz: 0.181
# skew: 0.074
# autocorrelation_66_lag: 0.073
# kurtosis: 0.026

# %% [markdown]
# **Wrapper methods**
#
# For a given learning algorithm, wrapper methods repeatedly select a subset of features and evaluate the selected features. Several procedures exist to select a subset but the most common are greedy and iterative; they either remove (backward selection) or add a feature (forward selection) sequentially.

# %%
# At each steps, SequentialFeatureSelector adds the best scoring feature to
# the set of selected features.
# For a given estimator, the score is computed with cross-validation.
knn = KNeighborsClassifier(n_neighbors=5)
sfs = SequentialFeatureSelector(
    knn, n_features_to_select=20, cv=5, scoring=make_scorer(accuracy_score)
)
sfs.fit(all_features, labels)

print("Selected features:")
print(all_features.columns[sfs.get_support()].tolist())
# Out:
# Selected features:
# ['fourier_200-220_Hz', 'fourier_120-140_Hz', 'autocorrelation_23_lag', 'largest_local_min_autocorrelation', 'fourier_60-80_Hz', 'autocorrelation_29_lag', 'autocorrelation_33_lag', 'autocorrelation_41_lag', 'fourier_40-60_Hz', 'lag_largest_local_min_autocorrelation_Hz', 'autocorrelation_19_lag', 'autocorrelation_13_lag', 'fourier_0-20_Hz', 'autocorrelation_5_lag', 'fourier_20-40_Hz', 'autocorrelation_66_lag', 'autocorrelation_73_lag', 'largest_local_max_autocorrelation', 'autocorrelation_49_lag', 'autocorrelation_57_lag']

# %% [markdown]
# ### Embedded methods
#
# Such methods use the intrinsic structure of a learning algorithm to embed feature selection into the underlying model.

# %%
rf = RandomForestClassifier().fit(all_features, labels)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Print features in descending order of importance, measured by the random forest feature importance (see the <tt>feature_importances_</tt> attribute).</p>
# </div>

# %%
rf.feature_importances_
# Out:
# array([0.05119875, 0.03482669, 0.03310695, 0.04832073, 0.03354193,
#        0.02818159, 0.03578438, 0.03517878, 0.02444962, 0.03126114,
#        0.03497272, 0.02739856, 0.02266917, 0.02527908, 0.03816066,
#        0.05121985, 0.03668346, 0.04036433, 0.0353718 , 0.03289169,
#        0.02631103, 0.056169  , 0.02755436, 0.03031838, 0.02646575,
#        0.0274831 , 0.03391672, 0.03931224, 0.03160754])

# %%
sorted(list(zip(rf.feature_names_in_, rf.feature_importances_)), key=lambda x: x[1], reverse=True)
# Out:
# [('min', np.float64(0.056168998982605335)),
#  ('max', np.float64(0.051219850462134606)),
#  ('fourier_780-800_Hz', np.float64(0.051198745866410655)),
#  ('fourier_120-140_Hz', np.float64(0.048320734151792846)),
#  ('autocorrelation_13_lag', np.float64(0.040364325162588886)),
#  ('autocorrelation_49_lag', np.float64(0.039312242518687535)),
#  ('kurtosis', np.float64(0.0381606597940753)),
#  ('autocorrelation_19_lag', np.float64(0.03668346177451385)),
#  ('fourier_80-100_Hz', np.float64(0.03578437965561931)),
#  ('fourier_0-20_Hz', np.float64(0.035371798704623265)),
#  ('fourier_60-80_Hz', np.float64(0.035178780095225376)),
#  ('autocorrelation_41_lag', np.float64(0.0349727225908022)),
#  ('fourier_400-420_Hz', np.float64(0.034826692072507735)),
#  ('lag_largest_local_max_autocorrelation_Hz', np.float64(0.03391672013725082)),
#  ('autocorrelation_23_lag', np.float64(0.033541927910492424)),
#  ('fourier_200-220_Hz', np.float64(0.033106954785406005)),
#  ('autocorrelation_5_lag', np.float64(0.03289169024744041)),
#  ('autocorrelation_57_lag', np.float64(0.0316075436771347)),
#  ('autocorrelation_33_lag', np.float64(0.03126114221086518)),
#  ('autocorrelation_66_lag', np.float64(0.030318382380899116)),
#  ('largest_local_min_autocorrelation', np.float64(0.028181589285316652)),
#  ('autocorrelation_81_lag', np.float64(0.027554356097560042)),
#  ('largest_local_max_autocorrelation', np.float64(0.027483096516088174)),
#  ('fourier_40-60_Hz', np.float64(0.027398561235112622)),
#  ('autocorrelation_73_lag', np.float64(0.026465746096462957)),
#  ('fourier_20-40_Hz', np.float64(0.026311028338625135)),
#  ('skew', np.float64(0.025279077645129173)),
#  ('autocorrelation_29_lag', np.float64(0.024449617861033442)),
#  ('lag_largest_local_min_autocorrelation_Hz',
#   np.float64(0.022669173743596463))]
